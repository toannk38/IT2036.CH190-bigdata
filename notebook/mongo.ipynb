# %%
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://127.0.0.1:27017")

# List all databases
print("Databases:")
for db_name in client.list_database_names():
    print(f"  - {db_name}")
    
    # Get collections for each database
    db = client[db_name]
    collections = db.list_collection_names()
    
    if collections:
        print("    Collections:")
        for collection_name in collections:
            print(f"      - {collection_name}")
    else:
        print("    No collections found")
    print()
# Out:
# Databases:
#   - admin
#     Collections:
#       - system.version
#
#   - config
#     Collections:
#       - system.sessions
#
#   - local
#     Collections:
#       - startup_log
#
#   - test_vietnam_stock_ai_error
#     Collections:
#       - symbols
#
#   - vietnam_stock_ai
#     Collections:
#       - final_scores
#       - llm_analysis
#       - ai_analysis
#       - price_history
#       - symbols
#       - news

# %%
client.vietnam_stock_ai.price_history.find_one()
# Out:
# {'_id': ObjectId('6942727ea6ed7c4ddad79c6e'),
#  'symbol': 'BID',
#  'timestamp': '2025-12-17T09:06:06.863256',
#  'open': 37.45,
#  'close': 38.0,
#  'high': 38.5,
#  'low': 37.45,
#  'volume': 4085100,
#  'created_at': '2025-12-17T09:06:06.874594'}

# %%
# import json
# from pymongo import MongoClient

# # Connect to MongoDB
# client = MongoClient()
# db = client.vietnam_stock_ai
# collection = db.symbols

# # Read JSON file
# with open("../data/vn30.json", "r", encoding="utf-8") as file:
#     data = json.load(file)

# for document in data:
#     document['active'] = True 
#  Insert records into MongoDB
# if isinstance(data, list):
#     collection.insert_many(data)
# else:
#     collection.insert_one(data)

# print(f"Successfully inserted {len(data) if isinstance(data, list) else 1} records")
# Out:
# [{'symbol': 'BID',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Đầu tư và Phát triển Việt Nam',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'BCM',
#   'organ_name': 'Tập đoàn Đầu tư và Phát triển Công nghiệp Becamex - CTCP',
#   'icb_name3': 'Bất động sản',
#   'icb_name2': 'Bất động sản',
#   'icb_name4': 'Bất động sản',
#   'com_type_code': 'CT',
#   'icb_code1': '8000',
#   'icb_code2': '8600',
#   'icb_code3': '8630',
#   'icb_code4': '8633',
#   'active': True},
#  {'symbol': 'DGC',
#   'organ_name': 'Công ty Cổ phần Tập đoàn Hóa chất Đức Giang',
#   'icb_name3': 'Hóa chất',
#   'icb_name2': 'Hóa chất',
#   'icb_name4': 'Sản phẩm hóa dầu, Nông dược & Hóa chất khác',
#   'com_type_code': 'CT',
#   'icb_code1': '1000',
#   'icb_code2': '1300',
#   'icb_code3': '1350',
#   'icb_code4': '1357',
#   'active': True},
#  {'symbol': 'FPT',
#   'organ_name': 'Công ty Cổ phần FPT',
#   'icb_name3': 'Phần mềm & Dịch vụ Máy tính',
#   'icb_name2': 'Công nghệ Thông tin',
#   'icb_name4': 'Phần mềm',
#   'com_type_code': 'CT',
#   'icb_code1': '9000',
#   'icb_code2': '9500',
#   'icb_code3': '9530',
#   'icb_code4': '9537',
#   'active': True},
#  {'symbol': 'GAS',
#   'organ_name': 'Tổng Công ty Khí Việt Nam - Công ty Cổ phần',
#   'icb_name3': 'Nước & Khí đốt',
#   'icb_name2': 'Điện, nước & xăng dầu khí đốt',
#   'icb_name4': 'Phân phối xăng dầu & khí đốt',
#   'com_type_code': 'CT',
#   'icb_code1': '7000',
#   'icb_code2': '7500',
#   'icb_code3': '7570',
#   'icb_code4': '7573',
#   'active': True},
#  {'symbol': 'HDB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Phát Triển Thành phố Hồ Chí Minh',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'CTG',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Công thương Việt Nam',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'MBB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Quân đội',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'HPG',
#   'organ_name': 'Công ty Cổ phần Tập đoàn Hòa Phát',
#   'icb_name3': 'Kim loại',
#   'icb_name2': 'Tài nguyên Cơ bản',
#   'icb_name4': 'Thép và sản phẩm thép',
#   'com_type_code': 'CT',
#   'icb_code1': '1000',
#   'icb_code2': '1700',
#   'icb_code3': '1750',
#   'icb_code4': '1757',
#   'active': True},
#  {'symbol': 'ACB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Á Châu',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'MWG',
#   'organ_name': 'Công ty Cổ phần Đầu tư Thế Giới Di Động',
#   'icb_name3': 'Bán lẻ',
#   'icb_name2': 'Bán lẻ',
#   'icb_name4': 'Phân phối hàng chuyên dụng',
#   'com_type_code': 'CT',
#   'icb_code1': '5000',
#   'icb_code2': '5300',
#   'icb_code3': '5370',
#   'icb_code4': '5379',
#   'active': True},
#  {'symbol': 'LPB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Lộc Phát Việt Nam',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'MSN',
#   'organ_name': 'Công ty Cổ phần Tập đoàn Masan',
#   'icb_name3': 'Sản xuất thực phẩm',
#   'icb_name2': 'Thực phẩm và đồ uống',
#   'icb_name4': 'Thực phẩm',
#   'com_type_code': 'CT',
#   'icb_code1': '3000',
#   'icb_code2': '3500',
#   'icb_code3': '3570',
#   'icb_code4': '3577',
#   'active': True},
#  {'symbol': 'PLX',
#   'organ_name': 'Tập đoàn Xăng dầu Việt Nam',
#   'icb_name3': 'Sản xuất Dầu khí',
#   'icb_name2': 'Dầu khí',
#   'icb_name4': 'Sản xuất và Khai thác dầu khí',
#   'com_type_code': 'CT',
#   'icb_code1': '0001',
#   'icb_code2': '0500',
#   'icb_code3': '0530',
#   'icb_code4': '0533',
#   'active': True},
#  {'symbol': 'SAB',
#   'organ_name': 'Tổng Công ty Cổ phần Bia - Rượu - Nước Giải khát Sài Gòn',
#   'icb_name3': 'Bia và đồ uống',
#   'icb_name2': 'Thực phẩm và đồ uống',
#   'icb_name4': 'Sản xuất bia',
#   'com_type_code': 'CT',
#   'icb_code1': '3000',
#   'icb_code2': '3500',
#   'icb_code3': '3530',
#   'icb_code4': '3533',
#   'active': True},
#  {'symbol': 'VHM',
#   'organ_name': 'Công ty Cổ phần Vinhomes',
#   'icb_name3': 'Bất động sản',
#   'icb_name2': 'Bất động sản',
#   'icb_name4': 'Bất động sản',
#   'com_type_code': 'CT',
#   'icb_code1': '8000',
#   'icb_code2': '8600',
#   'icb_code3': '8630',
#   'icb_code4': '8633',
#   'active': True},
#  {'symbol': 'VIB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Quốc tế Việt Nam',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'SSB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Đông Nam Á',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'SHB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Sài Gòn – Hà Nội',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'SSI',
#   'organ_name': 'Công ty Cổ phần Chứng khoán SSI',
#   'icb_name3': 'Dịch vụ tài chính',
#   'icb_name2': 'Dịch vụ tài chính',
#   'icb_name4': 'Môi giới chứng khoán',
#   'com_type_code': 'CK',
#   'icb_code1': '8000',
#   'icb_code2': '8700',
#   'icb_code3': '8770',
#   'icb_code4': '8777',
#   'active': True},
#  {'symbol': 'STB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Sài Gòn Thương Tín',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'TCB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Kỹ thương Việt Nam',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'TPB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Tiên Phong',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'VCB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Ngoại thương Việt Nam',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True},
#  {'symbol': 'GVR',
#   'organ_name': 'Tập đoàn Công nghiệp Cao su Việt Nam - Công ty Cổ phần',
#   'icb_name3': 'Hóa chất',
#   'icb_name2': 'Hóa chất',
#   'icb_name4': 'Nhựa, cao su & sợi',
#   'com_type_code': 'CT',
#   'icb_code1': '1000',
#   'icb_code2': '1300',
#   'icb_code3': '1350',
#   'icb_code4': '1353',
#   'active': True},
#  {'symbol': 'VIC',
#   'organ_name': 'Tập đoàn Vingroup - Công ty CP',
#   'icb_name3': 'Bất động sản',
#   'icb_name2': 'Bất động sản',
#   'icb_name4': 'Bất động sản',
#   'com_type_code': 'CT',
#   'icb_code1': '8000',
#   'icb_code2': '8600',
#   'icb_code3': '8630',
#   'icb_code4': '8633',
#   'active': True},
#  {'symbol': 'VJC',
#   'organ_name': 'Công ty Cổ phần Hàng không Vietjet',
#   'icb_name3': 'Du lịch & Giải trí',
#   'icb_name2': 'Du lịch và Giải trí',
#   'icb_name4': 'Hàng không',
#   'com_type_code': 'CT',
#   'icb_code1': '5000',
#   'icb_code2': '5700',
#   'icb_code3': '5750',
#   'icb_code4': '5751',
#   'active': True},
#  {'symbol': 'VRE',
#   'organ_name': 'Công ty Cổ phần Vincom Retail',
#   'icb_name3': 'Bất động sản',
#   'icb_name2': 'Bất động sản',
#   'icb_name4': 'Bất động sản',
#   'com_type_code': 'CT',
#   'icb_code1': '8000',
#   'icb_code2': '8600',
#   'icb_code3': '8630',
#   'icb_code4': '8633',
#   'active': True},
#  {'symbol': 'VNM',
#   'organ_name': 'Công ty Cổ phần Sữa Việt Nam',
#   'icb_name3': 'Sản xuất thực phẩm',
#   'icb_name2': 'Thực phẩm và đồ uống',
#   'icb_name4': 'Thực phẩm',
#   'com_type_code': 'CT',
#   'icb_code1': '3000',
#   'icb_code2': '3500',
#   'icb_code3': '3570',
#   'icb_code4': '3577',
#   'active': True},
#  {'symbol': 'VPB',
#   'organ_name': 'Ngân hàng Thương mại Cổ phần Việt Nam Thịnh Vượng',
#   'icb_name3': 'Ngân hàng',
#   'icb_name2': 'Ngân hàng',
#   'icb_name4': 'Ngân hàng',
#   'com_type_code': 'NH',
#   'icb_code1': '8301',
#   'icb_code2': '8300',
#   'icb_code3': '8350',
#   'icb_code4': '8355',
#   'active': True}]

# %%
# Out:
# Successfully inserted 30 records
